# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# 1.	Overview of the Data:
# - Understand the structure of the dataset, including the number of rows, columns, and data types.
# 2.	Summary Statistics
# -	Understand the central tendency, dispersion, and shape of the dataset’s distribution.
# 3.	Distribution of Numerical Features
# -	Visualize the distribution of numerical features to identify patterns, skewness, and potential outliers.
# 4.	Distribution of Categorical Features
# -	Analyzing the distribution of categorical features provides insights into the frequency and variability of categories.
# 5.	Correlation Analysis
# -	Understanding the relationship between numerical features.
# 6.	Identifying Missing Values
# -	Identify missing values to determine missing data and decide on appropriate imputation strategies.
# 7.	Outlier Detection
# -	Use box plots to identify outliers.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath('../scripts'))
from eda import *
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
df , df_definitions = load_data()
# Out:
# 2025-01-28 13:26:47,228 - INFO - Loading Data ...
# 2025-01-28 13:26:47,786 - INFO - Loading Data Finshed

# %% [markdown]
# ## Data Overview

# %%
df_definitions
# Out:
#              Column Name  \
# 0          TransactionId
# 1                BatchId
# 2              AccountId
# 3         SubscriptionId
# 4             CustomerId
# 5           CurrencyCode
# 6            CountryCode
# 7             ProviderId
# 8              ProductId
# 9        ProductCategory
# 10             ChannelId
# 11                Amount
# 12                 Value
# 13  TransactionStartTime
# 14       PricingStrategy
# 15           FraudResult
#
#                                                                                                            Definition
# 0                                                                          Unique �transaction identifier on platform
# 1                                                    Unique number assigned to a batch of transactions for processing
# 2                                                                  Unique number identifying the customer on platform
# 3                                                                 Unique number identifying the customer subscription
# 4                                                                               Unique identifier attached to Account
# 5                                                                                                    Country currency
# 6                                                                              Numerical geographical code of country
# 7                                                                                    Source provider of Item �bought.
# 8                                                                                             Item name being bought.
# 9                                                     ProductIds are organized into these broader product categories.
# 10                                               Identifies if customer used web,Android, IOS, pay later or checkout.
# 11  Value of the transaction. Positive for debits from customer account and negative for credit into customer account
# 12                                                                                       Absolute value of the amount
# 13                                                                                             Transaction start time
# 14                                                                Category of Xente's pricing structure for merchants
# 15                                                                         Fraud status of transaction 1 -yes or 0-No

# %%
df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
#       ProductCategory    ChannelId   Amount  Value  TransactionStartTime  \
# 0             airtime  ChannelId_3   1000.0   1000  2018-11-15T02:18:49Z
# 1  financial_services  ChannelId_2    -20.0     20  2018-11-15T02:19:08Z
# 2             airtime  ChannelId_3    500.0    500  2018-11-15T02:44:21Z
# 3        utility_bill  ChannelId_3  20000.0  21800  2018-11-15T03:32:55Z
# 4  financial_services  ChannelId_2   -644.0    644  2018-11-15T03:34:21Z
#
#    PricingStrategy  FraudResult
# 0                2            0
# 1                2            0
# 2                2            0
# 3                2            0
# 4                2            0

# %%
data_overview(df)
# Out:
# 2025-01-28 13:27:01,048 - INFO - Loading Data Overivew
# The shape of our Data is (95662, 16)
#
# Data Overview:
#                      Data Types  Number of missing values  Unique values
# CurrencyCode             object                         0              1
# CountryCode               int64                         0              1
# FraudResult               int64                         0              2
# ChannelId                object                         0              4
# PricingStrategy           int64                         0              4
# ProviderId               object                         0              6
# ProductCategory          object                         0              9
# ProductId                object                         0             23
# Value                     int64                         0           1517
# Amount                  float64                         0           1676
# SubscriptionId           object                         0           3627
# AccountId                object                         0           3633
# CustomerId               object                         0           3742
# TransactionStartTime     object                         0          94556
# BatchId                  object                         0          94809
# TransactionId            object                         0          95662

# %% [markdown]
# Insights
#
# - There are no missing values in our dataset. It is a cleaned dataset.
#
# - The only currency on our data os Ugandan Shilling(UGX).
#
# - Our data is collected from Uganda with 256 country code.
#
# - **Fraud Result** is our target variable with "0" and "1" as value.

# %% [markdown]
# ## Statistics Summary

# %%
summary(df)
# Out:
# 2025-01-28 13:27:07,535 - INFO -
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000
# Categorical Summary
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# unique                95662          94809            3633
# top     TransactionId_76871  BatchId_67019  AccountId_4841
# freq                      1             28           30893
#
#              SubscriptionId       CustomerId CurrencyCode    ProviderId  \
# count                 95662            95662        95662         95662
# unique                 3627             3742            1             6
# top     SubscriptionId_3829  CustomerId_7343          UGX  ProviderId_4
# freq                  32630             4091        95662         38189
#
#           ProductId     ProductCategory    ChannelId  TransactionStartTime
# count         95662               95662        95662                 95662
# unique           23                   9            4                 94556
# top     ProductId_6  financial_services  ChannelId_3  2018-12-24T16:30:13Z
# freq          32635               45405        56935                    17

# %% [markdown]
# ## Unique Features

# %%
col = ['FraudResult', 'ChannelId', 'PricingStrategy', 'ProviderId', 'ProductCategory', 'ProductId']

display(uniq(df, col))
# Out:
# 2025-01-28 13:27:12,641 - INFO - Unique Values in each columns
# 2 Unique values of FraudResult [0 1]
#
# 4 Unique values of ChannelId ['ChannelId_3' 'ChannelId_2' 'ChannelId_1' 'ChannelId_5']
#
# 4 Unique values of PricingStrategy [2 4 1 0]
#
# 6 Unique values of ProviderId ['ProviderId_6' 'ProviderId_4' 'ProviderId_1' 'ProviderId_5'
#  'ProviderId_3' 'ProviderId_2']
#
# 9 Unique values of ProductCategory ['airtime' 'financial_services' 'utility_bill' 'data_bundles' 'tv'
#  'transport' 'ticket' 'movies' 'other']
#
# 23 Unique values of ProductId ['ProductId_10' 'ProductId_6' 'ProductId_1' 'ProductId_21' 'ProductId_3'
#  'ProductId_15' 'ProductId_11' 'ProductId_19' 'ProductId_4' 'ProductId_5'
#  'ProductId_20' 'ProductId_9' 'ProductId_24' 'ProductId_14' 'ProductId_2'
#  'ProductId_13' 'ProductId_22' 'ProductId_8' 'ProductId_7' 'ProductId_27'
#  'ProductId_12' 'ProductId_16' 'ProductId_23']
# None

# %% [markdown]
# ## Distribution of Numerical Features

# %%
plot_numerical(df)
# Out:
# 2025-01-28 13:27:18,052 - INFO -  plotting numerical variables

# %% [markdown]
# **Insights**
#
# - Both Amount and Value donot distributed normally but are both are heavily rightly skewed.
# - The amount values enter negative implying it's credited.
# - values take the abolute values of amount so, no negative values is shown

# %% [markdown]
# ## Distribution of Categorical Features

# %% [markdown]
# - univariant Analysis

# %%
plot_cat(df,col)
# Out:
# 2025-01-28 13:27:31,383 - INFO - Plotting Categorical variables

# %% [markdown]
# ## Detecting outliers

# %% [markdown]
# - Detecting outliers in Amount and Value using Boxplot

# %%
plot_outliers(df)
# Out:
# 2025-01-28 13:27:39,536 - INFO - Plotting outliers using boxplot

# %% [markdown]
# - Detecting outliers using IQR

# %%
numerical = ['Amount', 'Value']
# Check for outliers and print the counts
lower_bounds, upper_bounds, outlier_counts = count_outliers_iqr(df,numerical)

# Print outlier counts for each column
for column, count in outlier_counts.items():
    print(f"Number of outliers in column '{column}': {count}")
# Out:
# 2025-01-28 13:27:49,944 - INFO - Detecting Outliers using IQR method
# Number of outliers in column 'Amount': 24441
# Number of outliers in column 'Value': 9021

# %% [markdown]
# ## Correlation Analysis

# %%
corr(df)
# Out:
# 2025-01-28 13:27:53,091 - INFO -  Correlation between numerical features
#                    Amount     Value  PricingStrategy  FraudResult
# Amount           1.000000  0.989692        -0.061931     0.557370
# Value            0.989692  1.000000        -0.017020     0.566739
# PricingStrategy -0.061931 -0.017020         1.000000    -0.033821
# FraudResult      0.557370  0.566739        -0.033821     1.000000

# %% [markdown]
# **Insights**
# - There is a high correlation between Amount and Value as expected.
# - There is also a positive correlation between both amount and value with Fraud Result. Which means If the amount value of the transcation increases the possibility of Fraud Result being one increased.

# %% [markdown]
# # Additional

# %% [markdown]
# ## MultiVariant Analysis

# %%
# Count the occurrences of each fraud result
fraud_counts = df['FraudResult'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(fraud_counts, labels=['Non-Fraud', 'Fraud'], autopct='%1.1f%%', startangle=90, colors=['lightblue', 'salmon'])
plt.title('Distribution of Fraud Results')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %% [markdown]
# **Exploring Fraud Results with other Features**
#
# - We have seen Fraud Reslut has a high correlation with Amount and values
#
# - From 95,662 Transactions 193 have default Fraud Result, which is 0.2%
# - 99.8% of the transactions have no fraud results

# %% [markdown]
# ### Amount and Fraud Result

# %%
percentiles = df['Amount'].quantile([i / 100 for i in range(101)])
value_at_1st = percentiles[0.01]
filtered_df = df[df['Amount'] <= value_at_1st] 
print('From ', filtered_df[filtered_df['FraudResult'] == 0].shape[0], 'transactions, There are ',  filtered_df[filtered_df['FraudResult'] == 1].shape[0], 'Transactions in one percentile of Amount that have default Fraud Result.','\n')
display(filtered_df[filtered_df['FraudResult'] == 1][[ 'CustomerId','Amount', 'Value','FraudResult']])
# Out:
# From  1224 transactions, There are  4 Transactions in one percentile of Amount that have default Fraud Result.
#             CustomerId    Amount   Value  FraudResult
# 55822  CustomerId_7339 -900000.0  900000            1
# 55841  CustomerId_7339 -500000.0  500000            1
# 56035  CustomerId_7401 -500000.0  500000            1
# 60834  CustomerId_7429 -500000.0  500000            1

# %%
percentiles = df['Amount'].quantile([i / 100 for i in range(101)])
value_at_99th = percentiles[0.99]
filtered_df = df[df['Amount'] >= value_at_99th] 
print('From ', filtered_df[filtered_df['FraudResult'] == 0].shape[0], 'transactions. There are ',  filtered_df[filtered_df['FraudResult'] == 1].shape[0], 'Transactions in above 99 percentile of Amount that have default Fraud Result.','\n')
display(filtered_df[filtered_df['FraudResult'] == 1][[ 'CustomerId','Amount', 'Value','FraudResult']])
# Out:
# From  908 transactions. There are  184 Transactions in above 99 percentile of Amount that have default Fraud Result.
#             CustomerId     Amount    Value  FraudResult
# 131    CustomerId_4275   700000.0   700000            1
# 146    CustomerId_7414   725000.0   725000            1
# 155    CustomerId_4275   700000.0   700000            1
# 2376   CustomerId_4134   700000.0   700000            1
# 2452   CustomerId_4275   700000.0   700000            1
# ...                ...        ...      ...          ...
# 94805  CustomerId_5155  2000000.0  2000000            1
# 95108  CustomerId_2303   500000.0   500000            1
# 95262  CustomerId_2303   500000.0   500000            1
# 95264  CustomerId_2303   500000.0   500000            1
# 95268  CustomerId_2303   500000.0   500000            1
#
# [184 rows x 4 columns]

# %%
percentiles = df['Value'].quantile([i / 100 for i in range(101)])
value_at_99th = percentiles[0.99]
filtered_df = df[df['Value'] >= value_at_99th] 
filtered_df[filtered_df['FraudResult'] == 1][[ 'CustomerId','Amount', 'Value','FraudResult']]
# Out:
#             CustomerId     Amount    Value  FraudResult
# 131    CustomerId_4275   700000.0   700000            1
# 146    CustomerId_7414   725000.0   725000            1
# 155    CustomerId_4275   700000.0   700000            1
# 2376   CustomerId_4134   700000.0   700000            1
# 2452   CustomerId_4275   700000.0   700000            1
# ...                ...        ...      ...          ...
# 94805  CustomerId_5155  2000000.0  2000000            1
# 95108  CustomerId_2303   500000.0   500000            1
# 95262  CustomerId_2303   500000.0   500000            1
# 95264  CustomerId_2303   500000.0   500000            1
# 95268  CustomerId_2303   500000.0   500000            1
#
# [188 rows x 4 columns]

# %%
df[df['FraudResult'] == 1].shape
# Out:
# (193, 16)

# %%
df[df['FraudResult'] == 1]['CustomerId'].nunique()
# Out:
# 54

# %%
df[df['FraudResult'] == 1]['CustomerId'].unique()
# Out:
# array(['CustomerId_4275', 'CustomerId_7414', 'CustomerId_4134',
#        'CustomerId_2353', 'CustomerId_4453', 'CustomerId_4391',
#        'CustomerId_5054', 'CustomerId_1858', 'CustomerId_2214',
#        'CustomerId_4878', 'CustomerId_1122', 'CustomerId_5105',
#        'CustomerId_2266', 'CustomerId_698', 'CustomerId_2143',
#        'CustomerId_2216', 'CustomerId_806', 'CustomerId_3467',
#        'CustomerId_5123', 'CustomerId_4128', 'CustomerId_2528',
#        'CustomerId_3768', 'CustomerId_1891', 'CustomerId_2292',
#        'CustomerId_4075', 'CustomerId_1680', 'CustomerId_2703',
#        'CustomerId_3956', 'CustomerId_2877', 'CustomerId_1302',
#        'CustomerId_1984', 'CustomerId_7339', 'CustomerId_4925',
#        'CustomerId_7401', 'CustomerId_7429', 'CustomerId_2445',
#        'CustomerId_856', 'CustomerId_1653', 'CustomerId_1567',
#        'CustomerId_1698', 'CustomerId_1850', 'CustomerId_865',
#        'CustomerId_1988', 'CustomerId_2656', 'CustomerId_1175',
#        'CustomerId_909', 'CustomerId_1602', 'CustomerId_7416',
#        'CustomerId_3075', 'CustomerId_4454', 'CustomerId_1535',
#        'CustomerId_682', 'CustomerId_5155', 'CustomerId_2303'],
#       dtype=object)

# %% [markdown]
# **Insights**
# - From 95,662 Transaction only 193 transactions are default.
# - From these 193 default transactions 188 transactions are by customers where the value of

# %%
df[df['FraudResult'] == 1].sort_values(by='Amount').head(10)
# Out:
#               TransactionId         BatchId       AccountId  \
# 55822   TransactionId_56954   BatchId_76447  AccountId_4249
# 60834  TransactionId_126320   BatchId_93368  AccountId_4249
# 56035   TransactionId_87682  BatchId_101919  AccountId_4249
# 55841   TransactionId_73797  BatchId_127642  AccountId_4249
# 68918   TransactionId_71725   BatchId_62457  AccountId_4841
# 68888   TransactionId_11592   BatchId_62469   AccountId_530
# 71689   TransactionId_52301   BatchId_76054  AccountId_1609
# 70492   TransactionId_78946   BatchId_13641  AccountId_1609
# 69570   TransactionId_63916   BatchId_36626  AccountId_1609
# 70529   TransactionId_47115  BatchId_115311  AccountId_1609
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 55822  SubscriptionId_4429  CustomerId_7339          UGX          256
# 60834  SubscriptionId_4429  CustomerId_7429          UGX          256
# 56035  SubscriptionId_4429  CustomerId_7401          UGX          256
# 55841  SubscriptionId_4429  CustomerId_7339          UGX          256
# 68918  SubscriptionId_3829   CustomerId_865          UGX          256
# 68888   SubscriptionId_135   CustomerId_865          UGX          256
# 71689  SubscriptionId_2872  CustomerId_1988          UGX          256
# 70492  SubscriptionId_2872  CustomerId_1988          UGX          256
# 69570  SubscriptionId_2872  CustomerId_1988          UGX          256
# 70529  SubscriptionId_2872  CustomerId_1988          UGX          256
#
#          ProviderId     ProductId     ProductCategory    ChannelId    Amount  \
# 55822  ProviderId_4   ProductId_3             airtime  ChannelId_2 -900000.0
# 60834  ProviderId_4   ProductId_3             airtime  ChannelId_2 -500000.0
# 56035  ProviderId_4   ProductId_3             airtime  ChannelId_2 -500000.0
# 55841  ProviderId_4  ProductId_10             airtime  ChannelId_2 -500000.0
# 68918  ProviderId_4   ProductId_6  financial_services  ChannelId_2   -1005.0
# 68888  ProviderId_6   ProductId_3             airtime  ChannelId_3     500.0
# 71689  ProviderId_3  ProductId_15  financial_services  ChannelId_3   30000.0
# 70492  ProviderId_3  ProductId_15  financial_services  ChannelId_3   50000.0
# 69570  ProviderId_3  ProductId_15  financial_services  ChannelId_3   50000.0
# 70529  ProviderId_3  ProductId_15  financial_services  ChannelId_3  100000.0
#
#         Value  TransactionStartTime  PricingStrategy  FraudResult
# 55822  900000  2019-01-10T15:48:59Z                4            1
# 60834  500000  2019-01-15T11:09:57Z                0            1
# 56035  500000  2019-01-10T21:27:12Z                4            1
# 55841  500000  2019-01-10T16:03:35Z                4            1
# 68918    1005  2019-01-23T09:15:37Z                2            1
# 68888     500  2019-01-23T08:55:16Z                2            1
# 71689   30000  2019-01-25T10:24:10Z                2            1
# 70492   50000  2019-01-24T21:02:07Z                2            1
# 69570   50000  2019-01-23T20:49:20Z                2            1
# 70529  100000  2019-01-24T21:42:23Z                2            1

# %%
df[df['FraudResult'] == 1].sort_values(by='Value').tail(10)
# Out:
#               TransactionId         BatchId       AccountId  \
# 82891   TransactionId_83769   BatchId_40333   AccountId_572
# 24529   TransactionId_95764    BatchId_2365  AccountId_1873
# 82314    TransactionId_7569  BatchId_123441   AccountId_572
# 65304   TransactionId_25959   BatchId_41544  AccountId_2043
# 93004   TransactionId_96894   BatchId_48649  AccountId_1178
# 93003  TransactionId_137519   BatchId_61860  AccountId_1178
# 87466   TransactionId_55014  BatchId_130638  AccountId_1178
# 92152   TransactionId_15293   BatchId_68761  AccountId_1178
# 87465   TransactionId_27985   BatchId_15818  AccountId_1178
# 87487   TransactionId_31461   BatchId_56005  AccountId_1178
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 82891  SubscriptionId_2950   CustomerId_909          UGX          256
# 24529  SubscriptionId_2964  CustomerId_2266          UGX          256
# 82314  SubscriptionId_2950   CustomerId_909          UGX          256
# 65304   SubscriptionId_842  CustomerId_2445          UGX          256
# 93004  SubscriptionId_2288  CustomerId_1535          UGX          256
# 93003  SubscriptionId_2288  CustomerId_1535          UGX          256
# 87466  SubscriptionId_2288  CustomerId_1535          UGX          256
# 92152  SubscriptionId_2288  CustomerId_1535          UGX          256
# 87465  SubscriptionId_2288  CustomerId_1535          UGX          256
# 87487  SubscriptionId_2288  CustomerId_1535          UGX          256
#
#          ProviderId     ProductId     ProductCategory    ChannelId     Amount  \
# 82891  ProviderId_5  ProductId_15  financial_services  ChannelId_3  5000000.0
# 24529  ProviderId_3  ProductId_15  financial_services  ChannelId_3  5000000.0
# 82314  ProviderId_5  ProductId_15  financial_services  ChannelId_3  7000000.0
# 65304  ProviderId_1  ProductId_15  financial_services  ChannelId_3  8600000.0
# 93004  ProviderId_1  ProductId_15  financial_services  ChannelId_3  9800000.0
# 93003  ProviderId_1  ProductId_15  financial_services  ChannelId_3  9850000.0
# 87466  ProviderId_1  ProductId_15  financial_services  ChannelId_3  9856000.0
# 92152  ProviderId_1  ProductId_15  financial_services  ChannelId_3  9860888.0
# 87465  ProviderId_1  ProductId_15  financial_services  ChannelId_3  9870000.0
# 87487  ProviderId_1  ProductId_15  financial_services  ChannelId_3  9880000.0
#
#          Value  TransactionStartTime  PricingStrategy  FraudResult
# 82891  5000000  2019-02-02T03:14:08Z                2            1
# 24529  5000000  2018-12-12T21:11:25Z                0            1
# 82314  7000000  2019-02-01T17:23:59Z                2            1
# 65304  8600000  2019-01-19T07:23:31Z                2            1
# 93004  9800000  2019-02-11T03:31:21Z                2            1
# 93003  9850000  2019-02-11T03:26:13Z                2            1
# 87466  9856000  2019-02-06T21:58:05Z                2            1
# 92152  9860888  2019-02-10T05:11:25Z                2            1
# 87465  9870000  2019-02-06T21:49:57Z                2            1
# 87487  9880000  2019-02-07T03:45:05Z                2            1

# %%
df[df['CustomerId'] == 'CustomerId_909']
# Out:
#               TransactionId         BatchId      AccountId  \
# 76569  TransactionId_135363   BatchId_27780  AccountId_572
# 76662  TransactionId_103109   BatchId_90376  AccountId_572
# 76667   TransactionId_16361   BatchId_10711  AccountId_572
# 76693  TransactionId_135392   BatchId_17770  AccountId_572
# 77481  TransactionId_110741   BatchId_17467  AccountId_572
# ...                     ...             ...            ...
# 82341   TransactionId_68589  BatchId_125935  AccountId_572
# 82891   TransactionId_83769   BatchId_40333  AccountId_572
# 82892   TransactionId_49929  BatchId_134443  AccountId_572
# 82893   TransactionId_41259   BatchId_29896  AccountId_572
# 82894  TransactionId_118160   BatchId_95619  AccountId_572
#
#             SubscriptionId      CustomerId CurrencyCode  CountryCode  \
# 76569  SubscriptionId_2950  CustomerId_909          UGX          256
# 76662  SubscriptionId_2950  CustomerId_909          UGX          256
# 76667  SubscriptionId_2950  CustomerId_909          UGX          256
# 76693  SubscriptionId_2950  CustomerId_909          UGX          256
# 77481  SubscriptionId_2950  CustomerId_909          UGX          256
# ...                    ...             ...          ...          ...
# 82341  SubscriptionId_2950  CustomerId_909          UGX          256
# 82891  SubscriptionId_2950  CustomerId_909          UGX          256
# 82892  SubscriptionId_2950  CustomerId_909          UGX          256
# 82893  SubscriptionId_2950  CustomerId_909          UGX          256
# 82894  SubscriptionId_2950  CustomerId_909          UGX          256
#
#          ProviderId     ProductId     ProductCategory    ChannelId     Amount  \
# 76569  ProviderId_5  ProductId_15  financial_services  ChannelId_3    95000.0
# 76662  ProviderId_5  ProductId_15  financial_services  ChannelId_3  1900000.0
# 76667  ProviderId_5  ProductId_15  financial_services  ChannelId_3  2450000.0
# 76693  ProviderId_5  ProductId_15  financial_services  ChannelId_3  2400000.0
# 77481  ProviderId_5  ProductId_15  financial_services  ChannelId_3    80000.0
# ...             ...           ...                 ...          ...        ...
# 82341  ProviderId_5  ProductId_15  financial_services  ChannelId_3  3000000.0
# 82891  ProviderId_5  ProductId_15  financial_services  ChannelId_3  5000000.0
# 82892  ProviderId_5  ProductId_15  financial_services  ChannelId_3  3000000.0
# 82893  ProviderId_1  ProductId_15  financial_services  ChannelId_3  5000000.0
# 82894  ProviderId_5  ProductId_15  financial_services  ChannelId_3  3000000.0
#
#          Value  TransactionStartTime  PricingStrategy  FraudResult
# 76569    95000  2019-01-28T17:28:02Z                2            0
# 76662  1900000  2019-01-28T18:28:42Z                2            1
# 76667  2450000  2019-01-28T18:32:24Z                2            1
# 76693  2400000  2019-01-28T18:56:37Z                2            0
# 77481    80000  2019-01-29T15:54:52Z                2            0
# ...        ...                   ...              ...          ...
# 82341  3000000  2019-02-01T17:29:20Z                0            1
# 82891  5000000  2019-02-02T03:14:08Z                2            1
# 82892  3000000  2019-02-02T03:14:58Z                2            1
# 82893  5000000  2019-02-02T03:19:05Z                2            1
# 82894  3000000  2019-02-02T03:19:49Z                2            1
#
# [115 rows x 16 columns]

# %%
fraud_counts = df[df['FraudResult'] == 1].sort_values(by='Value')['CustomerId'].value_counts()

# Filter to get only customers with exactly one fraud result
customers_with_one_fraud = fraud_counts[fraud_counts == 1]

# Get the list of CustomerIds
customer_list = customers_with_one_fraud.index.tolist()

# Display the list of customers
print('Customers with only 1 Fraud Result Record:',customer_list)
# Out:
# Customers with only 1 Fraud Result Record: ['CustomerId_7416', 'CustomerId_806', 'CustomerId_682', 'CustomerId_1122', 'CustomerId_1850', 'CustomerId_1653', 'CustomerId_4128', 'CustomerId_1602', 'CustomerId_3956', 'CustomerId_1891', 'CustomerId_2292', 'CustomerId_5123', 'CustomerId_4134', 'CustomerId_2656', 'CustomerId_2214', 'CustomerId_3467', 'CustomerId_4075', 'CustomerId_1984', 'CustomerId_1698', 'CustomerId_7429', 'CustomerId_2528', 'CustomerId_7401', 'CustomerId_2143', 'CustomerId_1680', 'CustomerId_698', 'CustomerId_2703', 'CustomerId_2877', 'CustomerId_5105']

# %%
# Plotting the fraud counts
plt.figure(figsize=(10, 6))
fraud_counts.plot(kind='bar', color='skyblue')

# Adding titles and labels
plt.title('Number of Fraudulent Transactions per Customer')
plt.xlabel('Customer ID')
plt.ylabel('Number of Fraudulent Transactions')

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Customers with default with their count
fraud = df[df['FraudResult'] == 1]['CustomerId'].nunique()
fraud_counts = df[df['FraudResult'] == 1].sort_values(by='Value')['CustomerId'].value_counts()

# Number of customers with Fraud results
print(f'Unique customer number in Default Fraud Results : {fraud}\n')

# Create a dictionary to store customer lists for each fraud count
customer_lists = {}

# Loop through counts from 1 to 8
for count in range(1, 9):
    # Get customers with exactly 'count' frauds
    customers = fraud_counts[fraud_counts == count].index.tolist()
    if customers:
        customer_lists[count] = customers

# Display the results
for count, customers in customer_lists.items():
    num_customers = len(customers)
    print(f"Customers with {count} fraud result are {num_customers} in number. These are:\n {', '.join(customers)}\n")

# Top 5 Customers
print('Top 5 customers with most Default transcations')
display(df[df['FraudResult'] == 1].sort_values(by='Value')['CustomerId'].value_counts().head())
# Out:
# Unique customer number in Default Fraud Results : 54
#
# Customers with 1 fraud result are 28 in number. These are:
#  CustomerId_7416, CustomerId_806, CustomerId_682, CustomerId_1122, CustomerId_1850, CustomerId_1653, CustomerId_4128, CustomerId_1602, CustomerId_3956, CustomerId_1891, CustomerId_2292, CustomerId_5123, CustomerId_4134, CustomerId_2656, CustomerId_2214, CustomerId_3467, CustomerId_4075, CustomerId_1984, CustomerId_1698, CustomerId_7429, CustomerId_2528, CustomerId_7401, CustomerId_2143, CustomerId_1680, CustomerId_698, CustomerId_2703, CustomerId_2877, CustomerId_5105
#
# Customers with 2 fraud result are 10 in number. These are:
#  CustomerId_2216, CustomerId_4454, CustomerId_4925, CustomerId_7339, CustomerId_7414, CustomerId_1175, CustomerId_2445, CustomerId_4391, CustomerId_1567, CustomerId_1858
#
# Customers with 3 fraud result are 3 in number. These are:
#  CustomerId_4275, CustomerId_1302, CustomerId_865
#
# Customers with 4 fraud result are 1 in number. These are:
#  CustomerId_856
#
# Customers with 5 fraud result are 1 in number. These are:
#  CustomerId_2353
#
# Customers with 6 fraud result are 2 in number. These are:
#  CustomerId_1535, CustomerId_3768
#
# Customers with 7 fraud result are 4 in number. These are:
#  CustomerId_5155, CustomerId_5054, CustomerId_3075, CustomerId_2266
#
# Customers with 8 fraud result are 1 in number. These are:
#  CustomerId_2303
#
# Top 5 customers with most Default transcations
# CustomerId
# CustomerId_909     31
# CustomerId_4878    22
# CustomerId_1988    14
# CustomerId_4453    12
# CustomerId_2303     8
# Name: count, dtype: int64

# %%
df[['Value','Amount']].describe()
# Out:
#               Value        Amount
# count  9.566200e+04  9.566200e+04
# mean   9.900584e+03  6.717846e+03
# std    1.231221e+05  1.233068e+05
# min    2.000000e+00 -1.000000e+06
# 25%    2.750000e+02 -5.000000e+01
# 50%    1.000000e+03  1.000000e+03
# 75%    5.000000e+03  2.800000e+03
# max    9.880000e+06  9.880000e+06

# %%
# Create a box plot to visualize the distribution of amounts by fraud result
plt.figure(figsize=(10, 6))
sns.boxplot(x='FraudResult', y='Amount', data=df, palette='pastel')

# Adding titles and labels
plt.title('Transaction Amounts by Fraud Result')
plt.xlabel('Fraud Result (0 = Legitimate, 1 = Fraudulent)')
plt.ylabel('Transaction Amount')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# 2025-01-28 13:29:10,395 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-28 13:29:10,784 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
print(f'Minimum value where transaction is legitimate:{df[df['FraudResult'] == 0]['Amount'].min()}\n Maximum value: {df[df['FraudResult'] == 0]['Amount'].max()}\n')
print(f'Minimum value where transaction is Default:{df[df['FraudResult'] == 1]['Amount'].min()}\n Maximum value: {df[df['FraudResult'] == 1]['Amount'].max()}\n')
# Out:
# Minimum value where transaction is legitimate:-1000000.0
#  Maximum value: 2400000.0
#
# Minimum value where transaction is Default:-900000.0
#  Maximum value: 9880000.0

# %%
# Create a box plot to visualize the distribution of amounts by fraud result
plt.figure(figsize=(10, 6))
sns.boxplot(x='FraudResult', y='Value', data=df, palette='pastel')

# Adding titles and labels
plt.title('Transaction Value by Fraud Result')
plt.xlabel('Fraud Result (0 = Legitimate, 1 = Fraudulent)')
plt.ylabel('Transaction Value')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# 2025-01-28 13:29:22,810 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-28 13:29:23,080 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
